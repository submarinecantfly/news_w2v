# %%
import pandas as pd
import sys

df = pd.read_csv('test_data.csv',encoding="gbk")

# %%
df
# Out:
#         id                                              title
# 0     2784                     美国地质勘探局：印度莫黑安东南部151公里处发生5.1级地震
# 1    12057                             美国MBA抵押贷款申请指数上周上升2.7%。
# 2    19620                        美国德州市长：预计将向印度供应更多的原油和液化天然气。
# 3    23768                               欧洲央行月报：仍需要足够程度的货币宽松。
# 4    23814            IMF：2017年11月委内瑞拉黄金持有量下降6.373吨至184.939吨。
# 5    28091                              YTN：朝鲜金正恩称，他将会和美国举行峰会
# 6    34581        美国副总统彭斯：（就朝鲜问题）为所有可能的结果做好准备将对任何核武器的使用进行快速应对
# 7    46930               香港财政司长陈茂波：需要继续留意全球货币环境和地缘政治的变化与政策风险。
# 8    51579                     日本央行理事雨宫正佳：退出宽松的细节将由经济和物价状况决定。
# 9    62560                 日本央行新任副行长：日本不存在通缩，但是距离2%的通胀目标仍有距离。
# 10   96556  美国明尼阿波利斯联储主席Kashkari称，美联储不能忽视发生全面性贸易战这一风险，美联储无...
# 11   97000                           德国地学研究中心：智利北部海岸附近发生6级地震。
# 12  105587    美国财长努钦：美国总统特朗普与朝鲜最高领导人金正恩会面的条件是朝鲜无核化以及不再进行导弹测试。
# 13  109969                                伊拉克总统：伊拉克支持欧佩克减产协定。
# ...

# %%
import heapq

# %%
a = [2,5,88,79,4]
heapq.nlargest(2,range(len(a)),a.__getitem__)
# Out:
# [2, 3]

# %%
import numpy as np 
a = np.zeros((50,1111))

# %%
a[2,6]
# Out:
# 0.0
